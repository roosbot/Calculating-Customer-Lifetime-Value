# %%
# Library import
import pandas as pd

# %%
# Read data
products_woo = pd.read_csv("./data/products_woo.csv")
products_ccv = pd.read_csv("./data/products_ccv.csv")

# %%
products_woo
# Out:
#      order_number  quantity  item_set  \
# 0             506         1         1
# 1             513         1         1
# 2             526         2         1
# 3             527         1         1
# 4             528         2         1
# ..            ...       ...       ...
# 320           899         3         0
# 321           900         3         0
# 322           901         3         0
# 323           902         3         0
# 324           903         4         0
#
#                                                  items
# 0               yerba mate 100 gram, bombilla, kalebas
# 1               yerba mate 100 gram, bombilla, kalebas
# 2    yerba mate 100 gram, bombilla, kalebas, yerba ...
# 3               yerba mate 100 gram, bombilla, kalebas
# 4               yerba mate 100 gram, bombilla, kalebas
# ..                                                 ...
# 320             yerba mate 500 gram, bombilla, kalebas
# 321             yerba mate 500 gram, bombilla, kalebas
# ...
